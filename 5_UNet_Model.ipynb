# %% [markdown]
# # Imports

# %%
# @title Install GraphCast
# %pip install --upgrade https://github.com/deepmind/graphcast/archive/master.zip

# %%
# Basic imports
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Plotting and animations
import cartopy 
import cartopy.crs as ccrs
import math
import ipywidgets as widgets
import datetime
from IPython.display import HTML
from matplotlib import animation
from typing import Optional

# Model
from UNet import *
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Plotting functions

# %%
def select(
    data: xr.Dataset,
    variable: str,
    level: Optional[int] = None,
    max_steps: Optional[int] = None
    ) -> xr.Dataset:
  data = data[variable]
  # if "batch" in data.dims:
  #   data = data.isel(batch=0)
  if max_steps is not None and "time" in data.sizes and max_steps < data.sizes["time"]:
    data = data.isel(time=range(0, max_steps))
  # if level is not None and "level" in data.coords:
  #   data = data.sel(level=level)
  return data

def scale(
    data: xr.Dataset,
    center: Optional[float] = None,
    robust: bool = False,
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:
  vmin = np.nanpercentile(data, (2 if robust else 0))
  vmax = np.nanpercentile(data, (98 if robust else 100))
  if center is not None:
    diff = max(vmax - center, center - vmin)
    vmin = center - diff
    vmax = center + diff
  return (data, matplotlib.colors.Normalize(vmin, vmax),
          ("RdBu_r" if center is not None else "viridis"))

def plot_data(
    data: dict[str, xr.Dataset],
    fig_title: str,
    plot_size: float = 5,
    robust: bool = False,
    cols: int = 4
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:

  first_data = next(iter(data.values()))[0]
  max_steps = first_data.sizes.get("time", 1)
  assert all(max_steps == d.sizes.get("time", 1) for d, _, _ in data.values())

  cols = min(cols, len(data))
  rows = math.ceil(len(data) / cols)

  figure = plt.figure(figsize=(plot_size * 2 * cols,
                               plot_size * rows))
  figure.suptitle(fig_title, fontsize=16)
  figure.subplots_adjust(wspace=0, hspace=0)
  figure.tight_layout()
  
  images = []
  for i, (title, (plot_data, norm, cmap)) in enumerate(data.items()):
    ax = figure.add_subplot(rows, cols, i+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(title)
    im = ax.imshow(
        plot_data.isel(time=0, missing_dims="ignore"), norm=norm,
        origin="lower", cmap=cmap)
    plt.colorbar(
        mappable=im,
        ax=ax,
        orientation="vertical",
        pad=0.02,
        aspect=16,
        shrink=0.75,
        cmap=cmap,
        extend=("both" if robust else "neither"))
    images.append(im)

  def update(frame):
      reference_date = datetime.datetime(1970, 1, 1)
      if "time" in first_data.dims:
        td = datetime.timedelta(microseconds=first_data["time"][frame].item() / 1000)
        td = reference_date + td
        figure.suptitle(f"{fig_title}, {td.strftime('%Y-%m-%d %H:%M:%S')}", fontsize=16)
      else:
        figure.suptitle(fig_title, fontsize=16)
      for im, (plot_data, norm, cmap) in zip(images, data.values()):
        im.set_data(plot_data.isel(time=frame, missing_dims="ignore"))

  ani = animation.FuncAnimation(
      fig=figure, func=update, frames=max_steps, interval=250)
  plt.close(figure.number)
  return HTML(ani.to_jshtml())

# %% [markdown]
# # Data load and visualization

# %%
ds = xr.open_dataset('ERA5_Data\WindComponents.nc')
# ds = xr.open_dataset('ERA5_Data/2023_SouthAfrica.nc')
# ds = ds.sel(expver=1).combine_first(ds.sel(expver=5))
ds.load()

ds['ws'] = (ds.u10**2 + ds.v10**2)**0.5

# ds = ds.sortby('latitude', ascending=True)
# ds = ds.assign_coords({"level": 1000})
# Out:
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# @title Choose data to plot

plot_example_variable = widgets.Dropdown(
    options=ds.data_vars.keys(),
    value="ws",
    description="Variable")
# plot_example_level = widgets.Dropdown(
#     options=ds.coords["level"].values,
#     value=1000,
#     description="Level")
plot_example_robust = widgets.Checkbox(value=True, description="Robust")
plot_example_max_steps = widgets.IntSlider(
    min=1, max=ds.dims["time"], value=6,
    description="Max steps")

widgets.VBox([
    plot_example_variable,
    # plot_example_level,
    plot_example_robust,
    plot_example_max_steps,
    widgets.Label(value="Run the next cell to plot the data. Rerunning this cell clears your selection.")
])
# Out:
# C:\Users\23603526\AppData\Local\Temp\ipykernel_4416\2430431530.py:13: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   min=1, max=ds.dims["time"], value=6,
# VBox(children=(Dropdown(description='Variable', index=2, options=('u10', 'v10', 'ws'), value='ws'), Checkbox(v…

# %%
plot_size = 7
level = 1000

data = {
    " ": scale(select(ds, plot_example_variable.value, level, plot_example_max_steps.value),
              robust=plot_example_robust.value),
}

fig_title = plot_example_variable.value

plot_data(data, fig_title, plot_size, plot_example_robust.value)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img9942cbdc841e4491a04d62b6d63264fa">
#   <div class="anim-controls">
#     <input id="_anim_slider9942cbdc841e4491a04d62b6d63264fa" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim9942cbdc841e4491a04d62b6d63264fa.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim9942cbdc841e4491a04d62b6d63264fa.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim9942cbdc841e4491a04d62b6d63264fa.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim9942cbdc841e4491a04d62b6d63264fa.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim9942cbdc841e4491a04d62b6d63264fa.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim9942cbdc841e4491a04d62b6d63264fa.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim9942cbdc841e4491a04d62b6d63264fa.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim9942cbdc841e4491a04d62b6d63264fa.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim9942cbdc841e4491a04d62b6d63264fa.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim9942cbdc841e4491a04d62b6d63264fa.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select9942cbdc841e4491a04d62b6d63264fa"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_9942cbdc841e4491a04d62b6d63264fa"
#              >
#       <label for="_anim_radio1_9942cbdc841e4491a04d62b6d63264fa">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_9942cbdc841e4491a04d62b6d63264fa"
#              checked>
#       <label for="_anim_radio2_9942cbdc841e4491a04d62b6d63264fa">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_9942cbdc841e4491a04d62b6d63264fa"
#              >
#       <label for="_anim_radio3_9942cbdc841e4491a04d62b6d63264fa">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img9942cbdc841e4491a04d62b6d63264fa";
#     var slider_id = "_anim_slider9942cbdc841e4491a04d62b6d63264fa";
#     var loop_select_id = "_anim_loop_select9942cbdc841e4491a04d62b6d63264fa";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABFeUlEQV

# %% [markdown]
# # Data Prep

# %%
# Training and validation data
# Windowed input of images to predict the next image
# def normalization(ds):
#     min_val = ds.min()
#     max_val = ds.max()

#     normalized_data = (ds - min_val) / (max_val - min_val)

#     normalized_data = xr.where(normalized_data < 0, 0, normalized_data)
#     normalized_data = xr.where(normalized_data > 1, 1, normalized_data)

#     return normalized_data  

window_size = 1
variable = plot_example_variable.value
# plot_shape = [3, 10, 30]

X, y = [], []

for i in range(ds.time.size - window_size):
    X.append(ds[variable].isel(time=slice(i, i + window_size)))
    y.append(ds[variable].isel(time=i + window_size))

X_ = np.array(X) # .reshape(-1, ds.longitude.size, ds.latitude.size, window_size)
y_ = np.array(y)

features = X_[0]
target = y_[0]

ax, fig = plt.subplots(1, window_size + 1, figsize=(20, 5))
for i in range(window_size):
    fig[i].imshow(features[i])
    fig[i].set_title(f'Input {i}')

fig[window_size].imshow(target)
fig[window_size].set_title('Target')
plt.colorbar(fig[window_size].imshow(target), ax=fig[window_size])
plt.show()

# %%
input_shape = X_.shape[1:]
split = round(X_.shape[0] * 0.9)

max_ws = X_.max()
X_n = X_ / max_ws
y_n = y_ / max_ws

X_n = X_n.reshape(-1, ds.latitude.size, ds.longitude.size, window_size)
y_n = y_n.reshape(-1, ds.latitude.size, ds.longitude.size,  1)

f_train, t_train = X_n[:split].astype('float32'), y_n[:split].astype('float32')
f_test, t_test = X_n[split:].astype('float32'), y_n[split:].astype('float32')
f_train.shape, t_train.shape, f_test.shape, t_test.shape
# Out:
# ((626, 10, 30, 1), (626, 10, 30, 1), (70, 10, 30, 1), (70, 10, 30, 1))

# %%
def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    # s2, p2 = encoder_block(p1, 128)
    # s3, p3 = encoder_block(p2, 256)
    # s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p1, 128) #Bridge

    # d1 = decoder_block(b1, s4, 512)
    # d2 = decoder_block(d1, s3, 256)
    # d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(b1, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)  #Binary (can be multiclass)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
input_shape = f_train.shape[1:]
output_shape = t_train.shape[1:] 
# output_shape = tuple(math.ceil(x / 3) for x in output_shape)
kernel_size = (1, 3)
pool_size = (2,2)
model = build_unet(input_shape)
model.summary()  

print(model.predict(f_train[0:1]).shape)
# Out:
# WARNING:tensorflow:From c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 10, 30, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 10, 30, 64)           640       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 10, 30, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 10, 30, 64)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 10, 30, 64)           36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 10, 30, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 10, 30, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 5, 15, 64)            0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 5, 15, 128)           73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 5, 15, 128)           512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 5, 15, 128)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 5, 15, 128)           147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 5, 15, 128)           512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 5, 15, 128)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_transpose (Conv2DTr  (None, 10, 30, 64)           32832     ['activation_3[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 10, 30, 128)          0         ['conv2d_transpose[0][0]',
#                                                                      'activation_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 10, 30, 64)           73792     ['concatenate[0][0]']
#
#  batch_normalization_4 (Bat  (None, 10, 30, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 10, 30, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 10, 30, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 10, 30, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 10, 30, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 10, 30, 1)            65        ['activation_5[0][0]']
#
# ==================================================================================================
# Total params: 404673 (1.54 MB)
# Trainable params: 403649 (1.54 MB)
# Non-trainable params: 1024 (4.00 KB)
# __________________________________________________________________________________________________
# 1/1 [==============================] - 0s 316ms/step
# (1, 10, 30, 1)

# %%
batch_size = 128
epochs = 500
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1, mode='min')

if True:
    history = model.fit(
        f_train, 
        t_train, 
        batch_size=batch_size, 
        epochs=epochs, 
        verbose=1, 
        validation_data=(f_test, t_test),
        callbacks=[early_stopping, model_checkpoint]
    )
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - ETA: 0s - loss: 0.0458
# Epoch 1: val_loss improved from inf to 0.03254, saving model to best_model.h5
# 5/5 [==============================] - 4s 372ms/step - loss: 0.0458 - val_loss: 0.0325
# Epoch 2/500
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 2: val_loss improved from 0.03254 to 0.03052, saving model to best_model.h5
# 5/5 [==============================] - 1s 291ms/step - loss: 0.0152 - val_loss: 0.0305
# Epoch 3/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 3: val_loss improved from 0.03052 to 0.02954, saving model to best_model.h5
# 5/5 [==============================] - 1s 253ms/step - loss: 0.0091 - val_loss: 0.0295
# Epoch 4/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0061
# Epoch 4: val_loss improved from 0.02954 to 0.02884, saving model to best_model.h5
# 5/5 [==============================] - 2s 306ms/step - loss: 0.0061 - val_loss: 0.0288
# Epoch 5/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0048
# Epoch 5: val_loss improved from 0.02884 to 0.02818, saving model to best_model.h5
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0048 - val_loss: 0.0282
# Epoch 6/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 6: val_loss improved from 0.02818 to 0.02788, saving model to best_model.h5
# 5/5 [==============================] - 2s 321ms/step - loss: 0.0045 - val_loss: 0.0279
# Epoch 7/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 7: val_loss improved from 0.02788 to 0.02754, saving model to best_model.h5
# 5/5 [==============================] - 1s 303ms/step - loss: 0.0042 - val_loss: 0.0275
# Epoch 8/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 8: val_loss improved from 0.02754 to 0.02732, saving model to best_model.h5
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0039 - val_loss: 0.0273
# Epoch 9/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 9: val_loss improved from 0.02732 to 0.02705, saving model to best_model.h5
# 5/5 [==============================] - 2s 342ms/step - loss: 0.0038 - val_loss: 0.0270
# Epoch 10/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 10: val_loss improved from 0.02705 to 0.02683, saving model to best_model.h5
# 5/5 [==============================] - 1s 304ms/step - loss: 0.0037 - val_loss: 0.0268
# Epoch 11/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 11: val_loss improved from 0.02683 to 0.02671, saving model to best_model.h5
# 5/5 [==============================] - 1s 293ms/step - loss: 0.0036 - val_loss: 0.0267
# Epoch 12/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0036
# Epoch 12: val_loss improved from 0.02671 to 0.02661, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0036 - val_loss: 0.0266
# Epoch 13/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 13: val_loss improved from 0.02661 to 0.02656, saving model to best_model.h5
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0035 - val_loss: 0.0266
# Epoch 14/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 14: val_loss improved from 0.02656 to 0.02646, saving model to best_model.h5
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0035 - val_loss: 0.0265
# Epoch 15/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 15: val_loss improved from 0.02646 to 0.02646, saving model to best_model.h5
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0034 - val_loss: 0.0265
# Epoch 16/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 16: val_loss improved from 0.02646 to 0.02645, saving model to best_model.h5
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0034 - val_loss: 0.0264
# Epoch 17/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 17: val_loss improved from 0.02645 to 0.02634, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0033 - val_loss: 0.0263
# Epoch 18/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 18: val_loss improved from 0.02634 to 0.02632, saving model to best_model.h5
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0033 - val_loss: 0.0263
# Epoch 19/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 19: val_loss improved from 0.02632 to 0.02622, saving model to best_model.h5
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0032 - val_loss: 0.0262
# Epoch 20/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 20: val_loss improved from 0.02622 to 0.02611, saving model to best_model.h5
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0032 - val_loss: 0.0261
# Epoch 21/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0032
# Epoch 21: val_loss improved from 0.02611 to 0.02609, saving model to best_model.h5
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0032 - val_loss: 0.0261
# Epoch 22/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 22: val_loss improved from 0.02609 to 0.02597, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0031 - val_loss: 0.0260
# Epoch 23/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 23: val_loss improved from 0.02597 to 0.02578, saving model to best_model.h5
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0031 - val_loss: 0.0258
# Epoch 24/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0031
# Epoch 24: val_loss did not improve from 0.02578
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0031 - val_loss: 0.0258
# Epoch 25/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 25: val_loss improved from 0.02578 to 0.02560, saving model to best_model.h5
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0030 - val_loss: 0.0256
# Epoch 26/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 26: val_loss improved from 0.02560 to 0.02544, saving model to best_model.h5
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0030 - val_loss: 0.0254
# Epoch 27/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 27: val_loss improved from 0.02544 to 0.02536, saving model to best_model.h5
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0030 - val_loss: 0.0254
# Epoch 28/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 28: val_loss improved from 0.02536 to 0.02519, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0030 - val_loss: 0.0252
# Epoch 29/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 29: val_loss improved from 0.02519 to 0.02491, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0030 - val_loss: 0.0249
# Epoch 30/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 30: val_loss improved from 0.02491 to 0.02475, saving model to best_model.h5
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0030 - val_loss: 0.0248
# Epoch 31/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0030
# Epoch 31: val_loss improved from 0.02475 to 0.02451, saving model to best_model.h5
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0030 - val_loss: 0.0245
# Epoch 32/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 32: val_loss improved from 0.02451 to 0.02435, saving model to best_model.h5
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0029 - val_loss: 0.0243
# Epoch 33/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 33: val_loss improved from 0.02435 to 0.02405, saving model to best_model.h5
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0029 - val_loss: 0.0240
# Epoch 34/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 34: val_loss improved from 0.02405 to 0.02398, saving model to best_model.h5
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0029 - val_loss: 0.0240
# Epoch 35/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 35: val_loss improved from 0.02398 to 0.02375, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0028 - val_loss: 0.0237
# Epoch 36/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 36: val_loss improved from 0.02375 to 0.02356, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0028 - val_loss: 0.0236
# Epoch 37/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0028
# Epoch 37: val_loss improved from 0.02356 to 0.02328, saving model to best_model.h5
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0028 - val_loss: 0.0233
# Epoch 38/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 38: val_loss improved from 0.02328 to 0.02312, saving model to best_model.h5
# 5/5 [==============================] - 1s 299ms/step - loss: 0.0027 - val_loss: 0.0231
# Epoch 39/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 39: val_loss improved from 0.02312 to 0.02266, saving model to best_model.h5
# 5/5 [==============================] - 1s 302ms/step - loss: 0.0027 - val_loss: 0.0227
# Epoch 40/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 40: val_loss improved from 0.02266 to 0.02258, saving model to best_model.h5
# 5/5 [==============================] - 1s 294ms/step - loss: 0.0027 - val_loss: 0.0226
# Epoch 41/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 41: val_loss improved from 0.02258 to 0.02229, saving model to best_model.h5
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0027 - val_loss: 0.0223
# Epoch 42/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 42: val_loss improved from 0.02229 to 0.02205, saving model to best_model.h5
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0027 - val_loss: 0.0221
# Epoch 43/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 43: val_loss improved from 0.02205 to 0.02177, saving model to best_model.h5
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0027 - val_loss: 0.0218
# Epoch 44/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 44: val_loss improved from 0.02177 to 0.02134, saving model to best_model.h5
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0027 - val_loss: 0.0213
# Epoch 45/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 45: val_loss improved from 0.02134 to 0.02123, saving model to best_model.h5
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0027 - val_loss: 0.0212
# Epoch 46/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 46: val_loss improved from 0.02123 to 0.02044, saving model to best_model.h5
# 5/5 [==============================] - 1s 277ms/step - loss: 0.0027 - val_loss: 0.0204
# Epoch 47/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 47: val_loss improved from 0.02044 to 0.02023, saving model to best_model.h5
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0027 - val_loss: 0.0202
# Epoch 48/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0027
# Epoch 48: val_loss improved from 0.02023 to 0.01992, saving model to best_model.h5
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0027 - val_loss: 0.0199
# Epoch 49/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 49: val_loss improved from 0.01992 to 0.01941, saving model to best_model.h5
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0026 - val_loss: 0.0194
# Epoch 50/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 50: val_loss improved from 0.01941 to 0.01925, saving model to best_model.h5
# 5/5 [==============================] - 2s 307ms/step - loss: 0.0026 - val_loss: 0.0192
# Epoch 51/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 51: val_loss improved from 0.01925 to 0.01881, saving model to best_model.h5
# 5/5 [==============================] - 2s 299ms/step - loss: 0.0026 - val_loss: 0.0188
# Epoch 52/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 52: val_loss improved from 0.01881 to 0.01817, saving model to best_model.h5
# 5/5 [==============================] - 1s 289ms/step - loss: 0.0025 - val_loss: 0.0182
# Epoch 53/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 53: val_loss improved from 0.01817 to 0.01805, saving model to best_model.h5
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0026 - val_loss: 0.0181
# Epoch 54/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 54: val_loss improved from 0.01805 to 0.01744, saving model to best_model.h5
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0025 - val_loss: 0.0174
# Epoch 55/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 55: val_loss improved from 0.01744 to 0.01718, saving model to best_model.h5
# 5/5 [==============================] - 1s 304ms/step - loss: 0.0025 - val_loss: 0.0172
# Epoch 56/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 56: val_loss improved from 0.01718 to 0.01675, saving model to best_model.h5
# 5/5 [==============================] - 1s 295ms/step - loss: 0.0025 - val_loss: 0.0167
# Epoch 57/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 57: val_loss improved from 0.01675 to 0.01621, saving model to best_model.h5
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0026 - val_loss: 0.0162
# Epoch 58/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 58: val_loss improved from 0.01621 to 0.01572, saving model to best_model.h5
# 5/5 [==============================] - 1s 291ms/step - loss: 0.0025 - val_loss: 0.0157
# Epoch 59/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0026
# Epoch 59: val_loss did not improve from 0.01572
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0026 - val_loss: 0.0158
# Epoch 60/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 60: val_loss improved from 0.01572 to 0.01504, saving model to best_model.h5
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0025 - val_loss: 0.0150
# Epoch 61/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 61: val_loss improved from 0.01504 to 0.01460, saving model to best_model.h5
# 5/5 [==============================] - 1s 281ms/step - loss: 0.0025 - val_loss: 0.0146
# Epoch 62/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 62: val_loss improved from 0.01460 to 0.01444, saving model to best_model.h5
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0025 - val_loss: 0.0144
# Epoch 63/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 63: val_loss improved from 0.01444 to 0.01383, saving model to best_model.h5
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0025 - val_loss: 0.0138
# Epoch 64/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 64: val_loss improved from 0.01383 to 0.01368, saving model to best_model.h5
# 5/5 [==============================] - 1s 292ms/step - loss: 0.0025 - val_loss: 0.0137
# Epoch 65/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 65: val_loss improved from 0.01368 to 0.01311, saving model to best_model.h5
# 5/5 [==============================] - 1s 286ms/step - loss: 0.0024 - val_loss: 0.0131
# Epoch 66/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 66: val_loss improved from 0.01311 to 0.01283, saving model to best_model.h5
# 5/5 [==============================] - 1s 296ms/step - loss: 0.0025 - val_loss: 0.0128
# Epoch 67/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 67: val_loss improved from 0.01283 to 0.01244, saving model to best_model.h5
# 5/5 [==============================] - 1s 296ms/step - loss: 0.0025 - val_loss: 0.0124
# Epoch 68/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 68: val_loss improved from 0.01244 to 0.01192, saving model to best_model.h5
# 5/5 [==============================] - 2s 321ms/step - loss: 0.0025 - val_loss: 0.0119
# Epoch 69/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 69: val_loss improved from 0.01192 to 0.01189, saving model to best_model.h5
# 5/5 [==============================] - 1s 297ms/step - loss: 0.0025 - val_loss: 0.0119
# Epoch 70/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 70: val_loss improved from 0.01189 to 0.01123, saving model to best_model.h5
# 5/5 [==============================] - 1s 289ms/step - loss: 0.0024 - val_loss: 0.0112
# Epoch 71/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 71: val_loss did not improve from 0.01123
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0024 - val_loss: 0.0113
# Epoch 72/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 72: val_loss improved from 0.01123 to 0.01093, saving model to best_model.h5
# 5/5 [==============================] - 1s 285ms/step - loss: 0.0024 - val_loss: 0.0109
# Epoch 73/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 73: val_loss improved from 0.01093 to 0.01037, saving model to best_model.h5
# 5/5 [==============================] - 2s 328ms/step - loss: 0.0024 - val_loss: 0.0104
# Epoch 74/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 74: val_loss improved from 0.01037 to 0.01027, saving model to best_model.h5
# 5/5 [==============================] - 2s 334ms/step - loss: 0.0025 - val_loss: 0.0103
# Epoch 75/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 75: val_loss improved from 0.01027 to 0.00968, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0025 - val_loss: 0.0097
# Epoch 76/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 76: val_loss improved from 0.00968 to 0.00926, saving model to best_model.h5
# 5/5 [==============================] - 1s 296ms/step - loss: 0.0025 - val_loss: 0.0093
# Epoch 77/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 77: val_loss did not improve from 0.00926
# 5/5 [==============================] - 1s 199ms/step - loss: 0.0024 - val_loss: 0.0093
# Epoch 78/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 78: val_loss improved from 0.00926 to 0.00894, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0024 - val_loss: 0.0089
# Epoch 79/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 79: val_loss improved from 0.00894 to 0.00835, saving model to best_model.h5
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0024 - val_loss: 0.0084
# Epoch 80/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 80: val_loss did not improve from 0.00835
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0025 - val_loss: 0.0086
# Epoch 81/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 81: val_loss improved from 0.00835 to 0.00798, saving model to best_model.h5
# 5/5 [==============================] - 2s 362ms/step - loss: 0.0024 - val_loss: 0.0080
# Epoch 82/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 82: val_loss did not improve from 0.00798
# 5/5 [==============================] - 1s 283ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 83/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 83: val_loss improved from 0.00798 to 0.00768, saving model to best_model.h5
# 5/5 [==============================] - 1s 308ms/step - loss: 0.0023 - val_loss: 0.0077
# Epoch 84/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 84: val_loss improved from 0.00768 to 0.00742, saving model to best_model.h5
# 5/5 [==============================] - 1s 280ms/step - loss: 0.0023 - val_loss: 0.0074
# Epoch 85/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 85: val_loss improved from 0.00742 to 0.00726, saving model to best_model.h5
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0023 - val_loss: 0.0073
# Epoch 86/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 86: val_loss improved from 0.00726 to 0.00674, saving model to best_model.h5
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0023 - val_loss: 0.0067
# Epoch 87/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 87: val_loss improved from 0.00674 to 0.00672, saving model to best_model.h5
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0023 - val_loss: 0.0067
# Epoch 88/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 88: val_loss improved from 0.00672 to 0.00665, saving model to best_model.h5
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 89/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 89: val_loss improved from 0.00665 to 0.00643, saving model to best_model.h5
# 5/5 [==============================] - 1s 274ms/step - loss: 0.0022 - val_loss: 0.0064
# Epoch 90/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 90: val_loss improved from 0.00643 to 0.00624, saving model to best_model.h5
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0023 - val_loss: 0.0062
# Epoch 91/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 91: val_loss did not improve from 0.00624
# 5/5 [==============================] - 1s 218ms/step - loss: 0.0022 - val_loss: 0.0064
# Epoch 92/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 92: val_loss improved from 0.00624 to 0.00596, saving model to best_model.h5
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0023 - val_loss: 0.0060
# Epoch 93/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 93: val_loss improved from 0.00596 to 0.00580, saving model to best_model.h5
# 5/5 [==============================] - 1s 254ms/step - loss: 0.0023 - val_loss: 0.0058
# Epoch 94/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 94: val_loss improved from 0.00580 to 0.00571, saving model to best_model.h5
# 5/5 [==============================] - 1s 259ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 95/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 95: val_loss improved from 0.00571 to 0.00557, saving model to best_model.h5
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0022 - val_loss: 0.0056
# Epoch 96/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 96: val_loss improved from 0.00557 to 0.00539, saving model to best_model.h5
# 5/5 [==============================] - 1s 238ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 97/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 97: val_loss improved from 0.00539 to 0.00539, saving model to best_model.h5
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 98/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 98: val_loss improved from 0.00539 to 0.00524, saving model to best_model.h5
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0022 - val_loss: 0.0052
# Epoch 99/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 99: val_loss improved from 0.00524 to 0.00515, saving model to best_model.h5
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 100/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 100: val_loss improved from 0.00515 to 0.00509, saving model to best_model.h5
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0021 - val_loss: 0.0051
# Epoch 101/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 101: val_loss improved from 0.00509 to 0.00509, saving model to best_model.h5
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0022 - val_loss: 0.0051
# Epoch 102/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 102: val_loss improved from 0.00509 to 0.00485, saving model to best_model.h5
# 5/5 [==============================] - 1s 263ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 103/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 103: val_loss improved from 0.00485 to 0.00484, saving model to best_model.h5
# 5/5 [==============================] - 1s 269ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 104/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 104: val_loss improved from 0.00484 to 0.00480, saving model to best_model.h5
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 105/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 105: val_loss improved from 0.00480 to 0.00477, saving model to best_model.h5
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 106/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 106: val_loss improved from 0.00477 to 0.00477, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 107/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 107: val_loss improved from 0.00477 to 0.00449, saving model to best_model.h5
# 5/5 [==============================] - 1s 256ms/step - loss: 0.0023 - val_loss: 0.0045
# Epoch 108/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 108: val_loss improved from 0.00449 to 0.00444, saving model to best_model.h5
# 5/5 [==============================] - 1s 249ms/step - loss: 0.0022 - val_loss: 0.0044
# Epoch 109/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 109: val_loss improved from 0.00444 to 0.00433, saving model to best_model.h5
# 5/5 [==============================] - 1s 252ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 110/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 110: val_loss improved from 0.00433 to 0.00428, saving model to best_model.h5
# 5/5 [==============================] - 1s 265ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 111/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 111: val_loss improved from 0.00428 to 0.00422, saving model to best_model.h5
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 112/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 112: val_loss improved from 0.00422 to 0.00415, saving model to best_model.h5
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0022 - val_loss: 0.0042
# Epoch 113/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 113: val_loss did not improve from 0.00415
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 114/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 114: val_loss did not improve from 0.00415
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 115/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 115: val_loss did not improve from 0.00415
# 5/5 [==============================] - 1s 251ms/step - loss: 0.0022 - val_loss: 0.0045
# Epoch 116/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 116: val_loss did not improve from 0.00415
# 5/5 [==============================] - 1s 279ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 117/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 117: val_loss improved from 0.00415 to 0.00411, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 118/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 118: val_loss improved from 0.00411 to 0.00406, saving model to best_model.h5
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 119/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 119: val_loss improved from 0.00406 to 0.00395, saving model to best_model.h5
# 5/5 [==============================] - 1s 267ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 120/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 120: val_loss improved from 0.00395 to 0.00391, saving model to best_model.h5
# 5/5 [==============================] - 1s 288ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 121/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 121: val_loss did not improve from 0.00391
# 5/5 [==============================] - 1s 230ms/step - loss: 0.0021 - val_loss: 0.0040
# Epoch 122/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 122: val_loss improved from 0.00391 to 0.00389, saving model to best_model.h5
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 123/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 123: val_loss improved from 0.00389 to 0.00380, saving model to best_model.h5
# 5/5 [==============================] - 1s 275ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 124/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 124: val_loss did not improve from 0.00380
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 125/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 125: val_loss improved from 0.00380 to 0.00358, saving model to best_model.h5
# 5/5 [==============================] - 1s 273ms/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 126/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 126: val_loss improved from 0.00358 to 0.00347, saving model to best_model.h5
# 5/5 [==============================] - 1s 266ms/step - loss: 0.0021 - val_loss: 0.0035
# Epoch 127/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 127: val_loss did not improve from 0.00347
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 128/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 128: val_loss did not improve from 0.00347
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 129/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 129: val_loss did not improve from 0.00347
# 5/5 [==============================] - 1s 225ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 130/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 130: val_loss did not improve from 0.00347
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 131/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 131: val_loss did not improve from 0.00347
# 5/5 [==============================] - 1s 217ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 132/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 132: val_loss improved from 0.00347 to 0.00342, saving model to best_model.h5
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 133/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 133: val_loss improved from 0.00342 to 0.00325, saving model to best_model.h5
# 5/5 [==============================] - 1s 262ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 134/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0021
# Epoch 134: val_loss did not improve from 0.00325
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0021 - val_loss: 0.0033
# Epoch 135/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 135: val_loss improved from 0.00325 to 0.00320, saving model to best_model.h5
# 5/5 [==============================] - 1s 257ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 136/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 136: val_loss did not improve from 0.00320
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0020 - val_loss: 0.0033
# Epoch 137/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 137: val_loss did not improve from 0.00320
# 5/5 [==============================] - 1s 203ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 138/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 138: val_loss did not improve from 0.00320
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 139/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 139: val_loss did not improve from 0.00320
# 5/5 [==============================] - 1s 229ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 140/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 140: val_loss improved from 0.00320 to 0.00315, saving model to best_model.h5
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 141/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 141: val_loss did not improve from 0.00315
# 5/5 [==============================] - 1s 207ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 142/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 142: val_loss did not improve from 0.00315
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 143/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 143: val_loss did not improve from 0.00315
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 144/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 144: val_loss improved from 0.00315 to 0.00299, saving model to best_model.h5
# 5/5 [==============================] - 1s 271ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 145/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 145: val_loss did not improve from 0.00299
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 146/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 146: val_loss did not improve from 0.00299
# 5/5 [==============================] - 1s 222ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 147/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 147: val_loss improved from 0.00299 to 0.00298, saving model to best_model.h5
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 148/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0020
# Epoch 148: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 149/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 149: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 150/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 150: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 151/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 151: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 152/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 152: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 213ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 153/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 153: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 210ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 154/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 154: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 155/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 155: val_loss did not improve from 0.00298
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 156/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 156: val_loss improved from 0.00298 to 0.00288, saving model to best_model.h5
# 5/5 [==============================] - 1s 246ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 157/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 157: val_loss did not improve from 0.00288
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 158/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 158: val_loss did not improve from 0.00288
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 159/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 159: val_loss did not improve from 0.00288
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 160/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 160: val_loss did not improve from 0.00288
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 161/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 161: val_loss improved from 0.00288 to 0.00286, saving model to best_model.h5
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 162/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 162: val_loss improved from 0.00286 to 0.00285, saving model to best_model.h5
# 5/5 [==============================] - 1s 240ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 163/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 163: val_loss did not improve from 0.00285
# 5/5 [==============================] - 1s 242ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 164/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 164: val_loss did not improve from 0.00285
# 5/5 [==============================] - 1s 226ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 165/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 165: val_loss improved from 0.00285 to 0.00284, saving model to best_model.h5
# 5/5 [==============================] - 1s 260ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 166/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 166: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 231ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 167/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 167: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 235ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 168/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 168: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 233ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 169/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 169: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 237ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 170/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 170: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 171/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 171: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 172/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 172: val_loss did not improve from 0.00284
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 173/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 173: val_loss improved from 0.00284 to 0.00283, saving model to best_model.h5
# 5/5 [==============================] - 1s 247ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 174/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 174: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 219ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 175/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 175: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 176/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 176: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 177/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 177: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 216ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 178/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 178: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 212ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 179/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 179: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 180/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 180: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 232ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 181/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 181: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 224ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 182/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 182: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 221ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 183/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 183: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 184/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 184: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 208ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 185/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 185: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 209ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 186/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 186: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 228ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 187/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 187: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 220ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 188/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0017
# Epoch 188: val_loss did not improve from 0.00283
# 5/5 [==============================] - 1s 214ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 188: early stopping

# %%
import matplotlib.pyplot as plt

pred = model.predict(f_test).reshape(-1, ds.latitude.size, ds.longitude.size)

seed = 0 
features = f_test[seed].reshape(window_size, ds.latitude.size, ds.longitude.size)
target = t_test[seed]

fig, ax = plt.subplots(1, window_size + 2, figsize=(20, 5))
for i in range(window_size):
    ax[i].imshow(features[i])
    ax[i].set_title(f'Input {i}')

ax[window_size].imshow(target)
ax[window_size].set_title('Target')

ax[window_size + 1].imshow(pred[0])
ax[window_size + 1].set_title('Prediction')

plt.colorbar(ax[window_size + 1].imshow(pred[0]), ax=ax[window_size + 1])

plt.tight_layout()
plt.show()
# Out:
# 3/3 [==============================] - 0s 22ms/step

# %%
pred.shape, t_test[0].shape
# Out:
# ((69, 10, 30), (10, 30, 1))

# %%
fig, ax = plt.subplots(10, 2, figsize=(20, 50))

pred_ = model.predict(f_test[0:1])  
pred = pred_.reshape(-1, ds.latitude.size, ds.longitude.size)

for i in range(10):
    ax[i, 0].imshow(t_test[i])
    ax[i, 0].set_title(f'Target {i + 1}')


    im = ax[i, 1].imshow(pred[0])
    ax[i, 1].set_title(f'Prediction {i + 1}')

    plt.colorbar(im, ax=ax[i, 1])

    pred_ = model.predict(pred_)
    pred = pred_.reshape(-1, ds.latitude.size, ds.longitude.size)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
