# %% [markdown]
# # Imports

# %%
# @title Install GraphCast
# %pip install --upgrade https://github.com/deepmind/graphcast/archive/master.zip
# Out:
# Collecting https://github.com/deepmind/graphcast/archive/master.zip
#   Using cached https://github.com/deepmind/graphcast/archive/master.zip
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: cartopy in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.23.0)
# Requirement already satisfied: chex in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.1.86)
# Requirement already satisfied: colabtools in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.0.1)
# Requirement already satisfied: dask in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (2024.4.1)
# Requirement already satisfied: dm-haiku in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.0.12)
# Requirement already satisfied: dm-tree in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.1.8)
# Requirement already satisfied: jax in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.4.26)
# Requirement already satisfied: jraph in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (0.0.6.dev0)
# Requirement already satisfied: matplotlib in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (3.8.2)
# Requirement already satisfied: numpy in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (1.26.4)
# Requirement already satisfied: pandas in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (2.2.0)
# Requirement already satisfied: rtree in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (1.2.0)
# Requirement already satisfied: scipy in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (1.12.0)
# Requirement already satisfied: trimesh in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (4.3.0)
# Requirement already satisfied: typing_extensions in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (4.9.0)
# Requirement already satisfied: xarray in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from graphcast==0.1) (2024.3.0)
# Requirement already satisfied: shapely>=1.7 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from cartopy->graphcast==0.1) (2.0.4)
# Requirement already satisfied: packaging>=20 in c:\users\23603526\appdata\roaming\python\python311\site-packages (from cartopy->graphcast==0.1) (23.2)
# Requirement already satisfied: pyshp>=2.3 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from cartopy->graphcast==0.1) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from cartopy->graphcast==0.1) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->graphcast==0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\23603526\appdata\roaming\python\python311\site-packages (from matplotlib->graphcast==0.1) (2.8.2)
# Requirement already satisfied: absl-py>=0.9.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from chex->graphcast==0.1) (2.1.0)
# Requirement already satisfied: jaxlib>=0.1.37 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from chex->graphcast==0.1) (0.4.26)
# Requirement already satisfied: toolz>=0.9.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from chex->graphcast==0.1) (0.12.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from jax->graphcast==0.1) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from jax->graphcast==0.1) (3.3.0)
# Requirement already satisfied: click>=8.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dask->graphcast==0.1) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dask->graphcast==0.1) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dask->graphcast==0.1) (2024.2.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dask->graphcast==0.1) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\23603526\appdata\roaming\python\python311\site-packages (from dask->graphcast==0.1) (6.0.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dask->graphcast==0.1) (7.1.0)
# Requirement already satisfied: jmp>=0.0.2 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dm-haiku->graphcast==0.1) (0.0.4)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dm-haiku->graphcast==0.1) (0.9.0)
# Requirement already satisfied: flax>=0.7.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from dm-haiku->graphcast==0.1) (0.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from pandas->graphcast==0.1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from pandas->graphcast==0.1) (2024.1)
# Requirement already satisfied: colorama in c:\users\23603526\appdata\roaming\python\python311\site-packages (from click>=8.1->dask->graphcast==0.1) (0.4.6)
# Requirement already satisfied: msgpack in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.1->dm-haiku->graphcast==0.1) (1.0.8)
# Requirement already satisfied: optax in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.1->dm-haiku->graphcast==0.1) (0.2.2)
# Requirement already satisfied: orbax-checkpoint in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.1->dm-haiku->graphcast==0.1) (0.5.9)
# Requirement already satisfied: tensorstore in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.1->dm-haiku->graphcast==0.1) (0.1.56)
# Requirement already satisfied: rich>=11.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from flax>=0.7.1->dm-haiku->graphcast==0.1) (13.7.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata>=4.13.0->dask->graphcast==0.1) (3.18.1)
# Requirement already satisfied: locket in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from partd>=1.2.0->dask->graphcast==0.1) (1.0.0)
# Requirement already satisfied: certifi in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from pyproj>=3.3.1->cartopy->graphcast==0.1) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\23603526\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->graphcast==0.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from rich>=11.1->flax>=0.7.1->dm-haiku->graphcast==0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\23603526\appdata\roaming\python\python311\site-packages (from rich>=11.1->flax>=0.7.1->dm-haiku->graphcast==0.1) (2.17.2)
# Requirement already satisfied: etils[epath,epy] in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku->graphcast==0.1) (1.8.0)
# Requirement already satisfied: nest_asyncio in c:\users\23603526\appdata\roaming\python\python311\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku->graphcast==0.1) (1.6.0)
# Requirement already satisfied: protobuf in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku->graphcast==0.1) (4.25.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.1->dm-haiku->graphcast==0.1) (0.1.2)
# Requirement already satisfied: importlib_resources in c:\users\23603526\appdata\local\programs\python\python311\lib\site-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.1->dm-haiku->graphcast==0.1) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Basic imports
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Plotting and animations
import cartopy 
import cartopy.crs as ccrs
import math
import ipywidgets as widgets
import datetime
from IPython.display import HTML
from matplotlib import animation
from typing import Optional

# Model
import keras
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Conv2D, Conv1D, MaxPooling2D, Dropout, Flatten, Reshape
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Plotting functions

# %%
def select(
    data: xr.Dataset,
    variable: str,
    level: Optional[int] = None,
    max_steps: Optional[int] = None
    ) -> xr.Dataset:
  data = data[variable]
  # if "batch" in data.dims:
  #   data = data.isel(batch=0)
  if max_steps is not None and "time" in data.sizes and max_steps < data.sizes["time"]:
    data = data.isel(time=range(0, max_steps))
  # if level is not None and "level" in data.coords:
  #   data = data.sel(level=level)
  return data

def scale(
    data: xr.Dataset,
    center: Optional[float] = None,
    robust: bool = False,
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:
  vmin = np.nanpercentile(data, (2 if robust else 0))
  vmax = np.nanpercentile(data, (98 if robust else 100))
  if center is not None:
    diff = max(vmax - center, center - vmin)
    vmin = center - diff
    vmax = center + diff
  return (data, matplotlib.colors.Normalize(vmin, vmax),
          ("RdBu_r" if center is not None else "viridis"))

def plot_data(
    data: dict[str, xr.Dataset],
    fig_title: str,
    plot_size: float = 5,
    robust: bool = False,
    cols: int = 4
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:

  first_data = next(iter(data.values()))[0]
  max_steps = first_data.sizes.get("time", 1)
  assert all(max_steps == d.sizes.get("time", 1) for d, _, _ in data.values())

  cols = min(cols, len(data))
  rows = math.ceil(len(data) / cols)

  figure = plt.figure(figsize=(plot_size * 2 * cols,
                               plot_size * rows))
  figure.suptitle(fig_title, fontsize=16)
  figure.subplots_adjust(wspace=0, hspace=0)
  figure.tight_layout()
  
  images = []
  for i, (title, (plot_data, norm, cmap)) in enumerate(data.items()):
    ax = figure.add_subplot(rows, cols, i+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(title)
    im = ax.imshow(
        plot_data.isel(time=0, missing_dims="ignore"), norm=norm,
        origin="lower", cmap=cmap)
    plt.colorbar(
        mappable=im,
        ax=ax,
        orientation="vertical",
        pad=0.02,
        aspect=16,
        shrink=0.75,
        cmap=cmap,
        extend=("both" if robust else "neither"))
    images.append(im)

  def update(frame):
      reference_date = datetime.datetime(1970, 1, 1)
      if "time" in first_data.dims:
        td = datetime.timedelta(microseconds=first_data["time"][frame].item() / 1000)
        td = reference_date + td
        figure.suptitle(f"{fig_title}, {td.strftime('%Y-%m-%d %H:%M:%S')}", fontsize=16)
      else:
        figure.suptitle(fig_title, fontsize=16)
      for im, (plot_data, norm, cmap) in zip(images, data.values()):
        im.set_data(plot_data.isel(time=frame, missing_dims="ignore"))

  ani = animation.FuncAnimation(
      fig=figure, func=update, frames=max_steps, interval=250)
  plt.close(figure.number)
  return HTML(ani.to_jshtml())

# %% [markdown]
# # Data load and visualization

# %%
ds = xr.open_dataset('ERA5_Data\WindComponents.nc')
# ds = xr.open_dataset('ERA5_Data/2023_SouthAfrica.nc')
# ds = ds.sel(expver=1).combine_first(ds.sel(expver=5))
ds.load()

ds['ws'] = (ds.u10**2 + ds.v10**2)**0.5

# ds = ds.sortby('latitude', ascending=True)
# ds = ds.assign_coords({"level": 1000})
# Out:
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# @title Choose data to plot

plot_example_variable = widgets.Dropdown(
    options=ds.data_vars.keys(),
    value="u10",
    description="Variable")
# plot_example_level = widgets.Dropdown(
#     options=ds.coords["level"].values,
#     value=1000,
#     description="Level")
plot_example_robust = widgets.Checkbox(value=True, description="Robust")
plot_example_max_steps = widgets.IntSlider(
    min=1, max=ds.dims["time"], value=6,
    description="Max steps")

widgets.VBox([
    plot_example_variable,
    # plot_example_level,
    plot_example_robust,
    plot_example_max_steps,
    widgets.Label(value="Run the next cell to plot the data. Rerunning this cell clears your selection.")
])
# Out:
# C:\Users\23603526\AppData\Local\Temp\ipykernel_22448\1985068130.py:13: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   min=1, max=ds.dims["time"], value=6,
# VBox(children=(Dropdown(description='Variable', options=('u10', 'v10', 'ws'), value='u10'), Checkbox(value=Tru…

# %%
plot_size = 7
level = 1000

data = {
    " ": scale(select(ds, plot_example_variable.value, level, plot_example_max_steps.value),
              robust=plot_example_robust.value),
}

fig_title = plot_example_variable.value

plot_data(data, fig_title, plot_size, plot_example_robust.value)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbd02732a87a240dc834dd2d91d8de7f6">
#   <div class="anim-controls">
#     <input id="_anim_sliderbd02732a87a240dc834dd2d91d8de7f6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbd02732a87a240dc834dd2d91d8de7f6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animbd02732a87a240dc834dd2d91d8de7f6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animbd02732a87a240dc834dd2d91d8de7f6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animbd02732a87a240dc834dd2d91d8de7f6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animbd02732a87a240dc834dd2d91d8de7f6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animbd02732a87a240dc834dd2d91d8de7f6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animbd02732a87a240dc834dd2d91d8de7f6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animbd02732a87a240dc834dd2d91d8de7f6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animbd02732a87a240dc834dd2d91d8de7f6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animbd02732a87a240dc834dd2d91d8de7f6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectbd02732a87a240dc834dd2d91d8de7f6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bd02732a87a240dc834dd2d91d8de7f6"
#              >
#       <label for="_anim_radio1_bd02732a87a240dc834dd2d91d8de7f6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bd02732a87a240dc834dd2d91d8de7f6"
#              checked>
#       <label for="_anim_radio2_bd02732a87a240dc834dd2d91d8de7f6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bd02732a87a240dc834dd2d91d8de7f6"
#              >
#       <label for="_anim_radio3_bd02732a87a240dc834dd2d91d8de7f6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbd02732a87a240dc834dd2d91d8de7f6";
#     var slider_id = "_anim_sliderbd02732a87a240dc834dd2d91d8de7f6";
#     var loop_select_id = "_anim_loop_selectbd02732a87a240dc834dd2d91d8de7f6";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABFeUlEQV

# %% [markdown]
# # Data Prep

# %%
# Training and validation data
# Windowed input of images to predict the next image
# def normalization(ds):
#     min_val = ds.min()
#     max_val = ds.max()

#     normalized_data = (ds - min_val) / (max_val - min_val)

#     normalized_data = xr.where(normalized_data < 0, 0, normalized_data)
#     normalized_data = xr.where(normalized_data > 1, 1, normalized_data)

#     return normalized_data  

window_size = 3
variable = plot_example_variable.value
# plot_shape = [3, 10, 30]

X, y = [], []

for i in range(ds.time.size - window_size):
    X.append(ds[variable].isel(time=slice(i, i + window_size)))
    y.append(ds[variable].isel(time=i + window_size))

X_ = np.array(X) # .reshape(-1, ds.longitude.size, ds.latitude.size, window_size)
y_ = np.array(y)

features = X_[0]
target = y_[0]

ax, fig = plt.subplots(1, window_size + 1, figsize=(20, 5))
for i in range(window_size):
    fig[i].imshow(features[i])
    fig[i].set_title(f'Input {i}')

fig[window_size].imshow(target)
fig[window_size].set_title('Target')
plt.colorbar(fig[window_size].imshow(target), ax=fig[window_size])
plt.show()

# %%
input_shape = X_.shape[1:]
split = round(X_.shape[0] * 0.9)

max_ws = X_.max()
X_n = X_ / max_ws
y_n = y_ / max_ws

X_n = X_n.reshape(-1, ds.latitude.size, ds.longitude.size, window_size)
y_n = y_n.reshape(-1, ds.latitude.size, ds.longitude.size,  1)

f_train, t_train = X_n[:split].astype('float32'), y_n[:split].astype('float32')
f_test, t_test = X_n[split:].astype('float32'), y_n[split:].astype('float32')
f_train.shape, t_train.shape, f_test.shape, t_test.shape
# Out:
# ((625, 10, 30, 3), (625, 10, 30, 1), (69, 10, 30, 3), (69, 10, 30, 1))

# %%
import math
def createModel(kernel_size, pool_size, input_shape, output_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size, padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, kernel_size, padding= 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size, padding='same', activation='relu'))
    model.add(Conv2D(64, kernel_size, padding = 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(0.25))

    model.add(Conv2D(32, kernel_size, padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv1D(1, 3, padding= 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    # model.add(Dropout(0.25))

    # model.add(Flatten())
    # model.add(Dense(512, activation='relu'))
    # model.add(Dropout(0.5))
    # model.add(Dense(output_shape[0] * output_shape[1], activation='softmax'))  # Adjust output layer shape

    # model.add(Reshape(output_shape))
    
    return model

input_shape = f_train.shape[1:]
output_shape = t_train.shape[1:] 
# output_shape = tuple(math.ceil(x / 3) for x in output_shape)
kernel_size = (1, 3)
pool_size = (2,2)
model = createModel(kernel_size, pool_size, input_shape, output_shape)
model.summary()  

print(model.predict(f_train[0:1]).shape)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_47 (Conv2D)          (None, 10, 30, 32)        320
#
#  conv2d_48 (Conv2D)          (None, 10, 30, 32)        3104
#
#  dropout_26 (Dropout)        (None, 10, 30, 32)        0
#
#  conv2d_49 (Conv2D)          (None, 10, 30, 64)        6208
#
#  conv2d_50 (Conv2D)          (None, 10, 30, 64)        12352
#
#  dropout_27 (Dropout)        (None, 10, 30, 64)        0
#
#  conv2d_51 (Conv2D)          (None, 10, 30, 32)        6176
#
#  conv1d_2 (Conv1D)           (None, 10, 30, 1)         97
#
# =================================================================
# Total params: 28257 (110.38 KB)
# Trainable params: 28257 (110.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 0s 69ms/step
# (1, 10, 30, 1)

# %%
batch_size = 128
epochs = 500
model.compile(optimizer='adam', loss='mse')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1, mode='min')

history = model.fit(
    f_train, 
    t_train, 
    batch_size=batch_size, 
    epochs=epochs, 
    verbose=1, 
    validation_data=(f_test, t_test),
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 1s 75ms/step - loss: 0.0284 - val_loss: 0.0254
# Epoch 2/500
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0271 - val_loss: 0.0265
# Epoch 3/500
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0267 - val_loss: 0.0254
# Epoch 4/500
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0263 - val_loss: 0.0261
# Epoch 5/500
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0261 - val_loss: 0.0253
# Epoch 6/500
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0260 - val_loss: 0.0257
# Epoch 7/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0259 - val_loss: 0.0252
# Epoch 8/500
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0259 - val_loss: 0.0255
# Epoch 9/500
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0259 - val_loss: 0.0252
# Epoch 10/500
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0259 - val_loss: 0.0253
# Epoch 11/500
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0259 - val_loss: 0.0254
# Epoch 12/500
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0258 - val_loss: 0.0252
# Epoch 13/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0259 - val_loss: 0.0252
# Epoch 14/500
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0258 - val_loss: 0.0253
# Epoch 15/500
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0258 - val_loss: 0.0252
# Epoch 16/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0257 - val_loss: 0.0253
# Epoch 17/500
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0257 - val_loss: 0.0252
# Epoch 18/500
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0257 - val_loss: 0.0251
# Epoch 19/500
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0257 - val_loss: 0.0253
# Epoch 20/500
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0257 - val_loss: 0.0251
# Epoch 21/500
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0257 - val_loss: 0.0252
# Epoch 22/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0258 - val_loss: 0.0253
# Epoch 23/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0257 - val_loss: 0.0251
# Epoch 24/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0257 - val_loss: 0.0251
# Epoch 25/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0256 - val_loss: 0.0252
# Epoch 26/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0256 - val_loss: 0.0251
# Epoch 27/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0257 - val_loss: 0.0250
# Epoch 28/500
# 5/5 [==============================] - 0s 68ms/step - loss: 0.
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0224 - val_loss: 0.0215
# Epoch 335/500
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0224 - val_loss: 0.0215
# Epoch 336/500
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 337/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 338/500
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0223 - val_loss: 0.0216
# Epoch 339/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0223 - val_loss: 0.0215
# Epoch 340/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0224 - val_loss: 0.0217
# Epoch 341/500
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0225 - val_loss: 0.0218
# Epoch 342/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0224 - val_loss: 0.0218
# Epoch 343/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0224 - val_loss: 0.0217
# Epoch 344/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0224 - val_loss: 0.0216
# Epoch 345/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 346/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0222 - val_loss: 0.0215
# Epoch 347/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 348/500
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 349/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 350/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 351/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0224 - val_loss: 0.0214
# Epoch 352/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0224 - val_loss: 0.0214
# Epoch 353/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0224 - val_loss: 0.0215
# Epoch 354/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0223 - val_loss: 0.0217
# Epoch 355/500
# 5/5 [==============================] - 0s 106ms/step - loss: 0.0223 - val_loss: 0.0216
# Epoch 356/500
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 357/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0223 - val_loss: 0.0215
# Epoch 358/500
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 359/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 360/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 361/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 362/500
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 363/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 364/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 365/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0222 - val_loss: 0.0215
# Epoch 366/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 367/500
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 368/500
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0223 - val_loss: 0.0215
# Epoch 369/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0223 - val_loss: 0.0213
# Epoch 370/500
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 371/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 372/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0222 - val_loss: 0.0214
# Epoch 373/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 374/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 375/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 376/500
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0222 - val_loss: 0.0215
# Epoch 377/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0221 - val_loss: 0.0214
# Epoch 378/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 379/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 380/500
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 381/500
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 382/500
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 383/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 384/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0222 - val_loss: 0.0212
# Epoch 385/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 386/500
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 387/500
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 388/500
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 389/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 390/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0220 - val_loss: 0.0213
# Epoch 391/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 392/500
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0222 - val_loss: 0.0212
# Epoch 393/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 394/500
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0222 - val_loss: 0.0213
# Epoch 395/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 396/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0221 - val_loss: 0.0215
# Epoch 397/500
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0222 - val_loss: 0.0216
# Epoch 398/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0222 - val_loss: 0.0212
# Epoch 399/500
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 400/500
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 401/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 402/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 403/500
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 404/500
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0221 - val_loss: 0.0213
# Epoch 405/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 406/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 407/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 408/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 409/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 410/500
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 411/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 412/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0221 - val_loss: 0.0211
# Epoch 413/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0221 - val_loss: 0.0212
# Epoch 414/500
# 5/5 [==============================] - 0s 107ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 415/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 416/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 417/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 418/500
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 419/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 420/500
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0220 - val_loss: 0.0213
# Epoch 421/500
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 422/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 423/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 424/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - val_loss: 0.0212
# Epoch 425/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 426/500
# 5/5 [==============================] - 0s 102ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 427/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 428/500
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 429/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 430/500
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 431/500
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 432/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 433/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 434/500
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 435/500
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0218 - val_loss: 0.0214
# Epoch 436/500
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0219 - val_loss: 0.0213
# Epoch 437/500
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 438/500
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 439/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 440/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 441/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 442/500
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0218 - val_loss: 0.0212
# Epoch 443/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 444/500
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 445/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0219 - val_loss: 0.0210
# Epoch 446/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 447/500
# 5/5 [==============================] - 0s 101ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 448/500
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0218 - val_loss: 0.0213
# Epoch 449/500
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 450/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0219 - val_loss: 0.0212
# Epoch 451/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0220 - val_loss: 0.0211
# Epoch 452/500
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 453/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0219 - val_loss: 0.0211
# Epoch 454/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0219 - val_loss: 0.0210
# Epoch 455/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0219 - val_loss: 0.0210
# Epoch 456/500
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 457/500
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 458/500
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 459/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 460/500
# 5/5 [==============================] - 0s 66ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 461/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0219 - val_loss: 0.0210
# Epoch 462/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 463/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0217 - val_loss: 0.0211
# Epoch 464/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0217 - val_loss: 0.0211
# Epoch 465/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 466/500
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 467/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0217 - val_loss: 0.0211
# Epoch 468/500
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 469/500
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 470/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 471/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 472/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 473/500
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 474/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0218 - val_loss: 0.0209
# Epoch 475/500
# 5/5 [==============================] - 0s 64ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 476/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 477/500
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 478/500
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 479/500
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 480/500
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 481/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 482/500
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 483/500
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 484/500
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 485/500
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0218 - val_loss: 0.0208
# Epoch 486/500
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 487/500
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 488/500
# 5/5 [==============================] - 0s 67ms/step - loss: 0.0218 - val_loss: 0.0210
# Epoch 489/500
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0218 - val_loss: 0.0209
# Epoch 490/500
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 491/500
# 5/5 [==============================] - 0s 105ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 492/500
# 5/5 [==============================] - 1s 96ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 493/500
# 5/5 [==============================] - 0s 99ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 494/500
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0217 - val_loss: 0.0208
# Epoch 495/500
# 5/5 [==============================] - 0s 96ms/step - loss: 0.0216 - val_loss: 0.0209
# Epoch 496/500
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0217 - val_loss: 0.0210
# Epoch 497/500
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0218 - val_loss: 0.0209
# Epoch 498/500
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0216 - val_loss: 0.0209
# Epoch 499/500
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0217 - val_loss: 0.0208
# Epoch 500/500
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0216 - val_loss: 0.0210

# %%
pred = model.predict(f_test).reshape(-1, ds.latitude.size, ds.longitude.size)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
# seed = 0
seed += 1
features = f_test[seed].reshape(window_size, ds.latitude.size, ds.longitude.size)
target = t_test[seed]

fig, ax = plt.subplots(1, window_size + 2, figsize=(20, 5))
ax[0].imshow(features[0])
ax[0].set_title('Input 0')
ax[1].imshow(features[1])
ax[1].set_title('Input 1')
ax[2].imshow(features[2])
ax[2].set_title('Input 2')
ax[3].imshow(target)
ax[3].set_title('Target')
ax[4].imshow(pred[seed])
ax[4].set_title('Prediction')
plt.colorbar(ax[4].imshow(pred[seed]), ax=ax[4])
plt.show()

# %%
plot_data(features, fig_title, plot_size, plot_example_robust.value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 plot_data(features, fig_title, plot_size, plot_example_robust.value)
#
# Cell In[2], line 38, in plot_data(data, fig_title, plot_size, robust, cols)
#      30 def plot_data(
#      31     data: dict[str, xr.Dataset],
#      32     fig_title: str,
#    (...)
#      35     cols: int = 4
#      36     ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:
# ---> 38   first_data = next(iter(data.values()))[0]
#      39   max_steps = first_data.sizes.get("time", 1)
#      40   assert all(max_steps == d.sizes.get("time", 1) for d, _, _ in data.values())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
