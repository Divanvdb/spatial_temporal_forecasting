# %% [markdown]
# # Imports

# %%
# @title Install GraphCast
# %pip install --upgrade https://github.com/deepmind/graphcast/archive/master.zip

# %%
# Basic imports
import xarray as xr
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Plotting and animations
import cartopy 
import cartopy.crs as ccrs
import math
import ipywidgets as widgets
import datetime
from IPython.display import HTML
from matplotlib import animation
from typing import Optional

# Model
import keras
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense, Conv2D, Conv1D, MaxPooling2D, Dropout, Flatten, Reshape
from tensorflow.keras.layers import AveragePooling2D, UpSampling2D, Concatenate
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Plotting functions

# %%
def select(
    data: xr.Dataset,
    variable: str,
    level: Optional[int] = None,
    max_steps: Optional[int] = None
    ) -> xr.Dataset:
  data = data[variable]
  # if "batch" in data.dims:
  #   data = data.isel(batch=0)
  if max_steps is not None and "time" in data.sizes and max_steps < data.sizes["time"]:
    data = data.isel(time=range(0, max_steps))
  # if level is not None and "level" in data.coords:
  #   data = data.sel(level=level)
  return data

def scale(
    data: xr.Dataset,
    center: Optional[float] = None,
    robust: bool = False,
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:
  vmin = np.nanpercentile(data, (2 if robust else 0))
  vmax = np.nanpercentile(data, (98 if robust else 100))
  if center is not None:
    diff = max(vmax - center, center - vmin)
    vmin = center - diff
    vmax = center + diff
  return (data, matplotlib.colors.Normalize(vmin, vmax),
          ("RdBu_r" if center is not None else "viridis"))

def plot_data(
    data: dict[str, xr.Dataset],
    fig_title: str,
    plot_size: float = 5,
    robust: bool = False,
    cols: int = 4
    ) -> tuple[xr.Dataset, matplotlib.colors.Normalize, str]:

  first_data = next(iter(data.values()))[0]
  max_steps = first_data.sizes.get("time", 1)
  assert all(max_steps == d.sizes.get("time", 1) for d, _, _ in data.values())

  cols = min(cols, len(data))
  rows = math.ceil(len(data) / cols)

  figure = plt.figure(figsize=(plot_size * 2 * cols,
                               plot_size * rows))
  figure.suptitle(fig_title, fontsize=16)
  figure.subplots_adjust(wspace=0, hspace=0)
  figure.tight_layout()
  
  images = []
  for i, (title, (plot_data, norm, cmap)) in enumerate(data.items()):
    ax = figure.add_subplot(rows, cols, i+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(title)
    im = ax.imshow(
        plot_data.isel(time=0, missing_dims="ignore"), norm=norm,
        origin="lower", cmap=cmap)
    plt.colorbar(
        mappable=im,
        ax=ax,
        orientation="vertical",
        pad=0.02,
        aspect=16,
        shrink=0.75,
        cmap=cmap,
        extend=("both" if robust else "neither"))
    images.append(im)

  def update(frame):
      reference_date = datetime.datetime(1970, 1, 1)
      if "time" in first_data.dims:
        td = datetime.timedelta(microseconds=first_data["time"][frame].item() / 1000)
        td = reference_date + td
        figure.suptitle(f"{fig_title}, {td.strftime('%Y-%m-%d %H:%M:%S')}", fontsize=16)
      else:
        figure.suptitle(fig_title, fontsize=16)
      for im, (plot_data, norm, cmap) in zip(images, data.values()):
        im.set_data(plot_data.isel(time=frame, missing_dims="ignore"))

  ani = animation.FuncAnimation(
      fig=figure, func=update, frames=max_steps, interval=250)
  plt.close(figure.number)
  return HTML(ani.to_jshtml())

# %% [markdown]
# # Data load and visualization

# %%
ds = xr.open_dataset('ERA5_Data\WindComponents.nc')
# ds = xr.open_dataset('ERA5_Data/2023_SouthAfrica.nc')
# ds = ds.sel(expver=1).combine_first(ds.sel(expver=5))
ds.load()

ds['ws'] = (ds.u10**2 + ds.v10**2)**0.5

# ds = ds.sortby('latitude', ascending=True)
# ds = ds.assign_coords({"level": 1000})
# Out:
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# @title Choose data to plot

plot_example_variable = widgets.Dropdown(
    options=ds.data_vars.keys(),
    value="ws",
    description="Variable")
# plot_example_level = widgets.Dropdown(
#     options=ds.coords["level"].values,
#     value=1000,
#     description="Level")
plot_example_robust = widgets.Checkbox(value=True, description="Robust")
plot_example_max_steps = widgets.IntSlider(
    min=1, max=ds.dims["time"], value=6,
    description="Max steps")

widgets.VBox([
    plot_example_variable,
    # plot_example_level,
    plot_example_robust,
    plot_example_max_steps,
    widgets.Label(value="Run the next cell to plot the data. Rerunning this cell clears your selection.")
])
# Out:
# C:\Users\23603526\AppData\Local\Temp\ipykernel_4236\2430431530.py:13: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   min=1, max=ds.dims["time"], value=6,
# VBox(children=(Dropdown(description='Variable', index=2, options=('u10', 'v10', 'ws'), value='ws'), Checkbox(v…

# %%
plot_size = 7
level = 1000

data = {
    " ": scale(select(ds, plot_example_variable.value, level, plot_example_max_steps.value),
              robust=plot_example_robust.value),
}

fig_title = plot_example_variable.value

plot_data(data, fig_title, plot_size, plot_example_robust.value)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img3428fc6c4b124673bf1d9c847d65f5e9">
#   <div class="anim-controls">
#     <input id="_anim_slider3428fc6c4b124673bf1d9c847d65f5e9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim3428fc6c4b124673bf1d9c847d65f5e9.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim3428fc6c4b124673bf1d9c847d65f5e9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select3428fc6c4b124673bf1d9c847d65f5e9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_3428fc6c4b124673bf1d9c847d65f5e9"
#              >
#       <label for="_anim_radio1_3428fc6c4b124673bf1d9c847d65f5e9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_3428fc6c4b124673bf1d9c847d65f5e9"
#              checked>
#       <label for="_anim_radio2_3428fc6c4b124673bf1d9c847d65f5e9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_3428fc6c4b124673bf1d9c847d65f5e9"
#              >
#       <label for="_anim_radio3_3428fc6c4b124673bf1d9c847d65f5e9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3428fc6c4b124673bf1d9c847d65f5e9";
#     var slider_id = "_anim_slider3428fc6c4b124673bf1d9c847d65f5e9";
#     var loop_select_id = "_anim_loop_select3428fc6c4b124673bf1d9c847d65f5e9";
#     var frames = new Array(6);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAABFeUlEQV

# %% [markdown]
# # Data Prep

# %%
# Training and validation data
# Windowed input of images to predict the next image
# def normalization(ds):
#     min_val = ds.min()
#     max_val = ds.max()

#     normalized_data = (ds - min_val) / (max_val - min_val)

#     normalized_data = xr.where(normalized_data < 0, 0, normalized_data)
#     normalized_data = xr.where(normalized_data > 1, 1, normalized_data)

#     return normalized_data  

window_size = 2
variable = plot_example_variable.value
# plot_shape = [3, 10, 30]

X, y = [], []

for i in range(ds.time.size - window_size):
    X.append(ds[variable].isel(time=slice(i, i + window_size)))
    y.append(ds[variable].isel(time=i + window_size))

X_ = np.array(X) # .reshape(-1, ds.longitude.size, ds.latitude.size, window_size)
y_ = np.array(y)

features = X_[0]
target = y_[0]

ax, fig = plt.subplots(1, window_size + 1, figsize=(20, 5))
for i in range(window_size):
    fig[i].imshow(features[i])
    fig[i].set_title(f'Input {i}')

fig[window_size].imshow(target)
fig[window_size].set_title('Target')
plt.colorbar(fig[window_size].imshow(target), ax=fig[window_size])
plt.show()

# %%
input_shape = X_.shape[1:]
split = round(X_.shape[0] * 0.9)

max_ws = X_.max()
X_n = X_ / max_ws
y_n = y_ / max_ws

X_n = X_n.reshape(-1, ds.latitude.size, ds.longitude.size, window_size)
y_n = y_n.reshape(-1, ds.latitude.size, ds.longitude.size,  1)

f_train, t_train = X_n[:split].astype('float32'), y_n[:split].astype('float32')
f_test, t_test = X_n[split:].astype('float32'), y_n[split:].astype('float32')
f_train.shape, t_train.shape, f_test.shape, t_test.shape
# Out:
# ((626, 10, 30, 2), (626, 10, 30, 1), (69, 10, 30, 2), (69, 10, 30, 1))

# %%
def createModel(kernel_size, pool_size, input_shape, output_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size, padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv2D(32, kernel_size, padding= 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size, padding='same', activation='relu'))
    model.add(Conv2D(64, kernel_size, padding = 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(0.25))

    model.add(Conv2D(32, kernel_size, padding='same', activation='relu', input_shape=input_shape))
    model.add(Conv1D(1, 3, padding= 'same', activation='relu'))
    # model.add(MaxPooling2D(pool_size=pool_size))
    # model.add(Dropout(0.25))

    # model.add(Flatten())
    # model.add(Dense(512, activation='relu'))
    # model.add(Dropout(0.5))
    # model.add(Dense(output_shape[0] * output_shape[1], activation='softmax'))  # Adjust output layer shape

    # model.add(Reshape(output_shape))
    
    return model



input_shape = f_train.shape[1:]
output_shape = t_train.shape[1:] 
# output_shape = tuple(math.ceil(x / 3) for x in output_shape)
kernel_size = (1, 3)
pool_size = (2,2)
model = createModel(kernel_size, pool_size, input_shape, output_shape)
model.summary()  

print(model.predict(f_train[0:1]).shape)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_35 (Conv2D)          (None, 10, 30, 32)        224
#
#  conv2d_36 (Conv2D)          (None, 10, 30, 32)        3104
#
#  dropout_4 (Dropout)         (None, 10, 30, 32)        0
#
#  conv2d_37 (Conv2D)          (None, 10, 30, 64)        6208
#
#  conv2d_38 (Conv2D)          (None, 10, 30, 64)        12352
#
#  dropout_5 (Dropout)         (None, 10, 30, 64)        0
#
#  conv2d_39 (Conv2D)          (None, 10, 30, 32)        6176
#
#  conv1d_2 (Conv1D)           (None, 10, 30, 1)         97
#
# =================================================================
# Total params: 28161 (110.00 KB)
# Trainable params: 28161 (110.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 1/1 [==============================] - 0s 76ms/step
# (1, 10, 30, 1)

# %%
batch_size = 128
epochs = 500
model.compile(optimizer='adam', loss='mse')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=15, verbose=1, mode='min')
model_checkpoint = ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, verbose=1, mode='min')

if True:
    history = model.fit(
        f_train, 
        t_train, 
        batch_size=batch_size, 
        epochs=epochs, 
        verbose=1, 
        validation_data=(f_test, t_test),
        callbacks=[early_stopping, model_checkpoint]
    )
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 5/5 [==============================] - ETA: 0s - loss: 0.2000
# Epoch 1: val_loss improved from inf to 0.05446, saving model to best_model.h5
# 5/5 [==============================] - 2s 158ms/step - loss: 0.2000 - val_loss: 0.0545
# Epoch 2/500
# c:\Users\23603526\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 5/5 [==============================] - ETA: 0s - loss: 0.0813
# Epoch 2: val_loss improved from 0.05446 to 0.05159, saving model to best_model.h5
# 5/5 [==============================] - 1s 127ms/step - loss: 0.0813 - val_loss: 0.0516
# Epoch 3/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0602
# Epoch 3: val_loss did not improve from 0.05159
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0602 - val_loss: 0.0716
# Epoch 4/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0629
# Epoch 4: val_loss did not improve from 0.05159
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0629 - val_loss: 0.0535
# Epoch 5/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0521
# Epoch 5: val_loss improved from 0.05159 to 0.04405, saving model to best_model.h5
# 5/5 [==============================] - 1s 118ms/step - loss: 0.0521 - val_loss: 0.0441
# Epoch 6/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0497
# Epoch 6: val_loss did not improve from 0.04405
# 5/5 [==============================] - 0s 107ms/step - loss: 0.0497 - val_loss: 0.0457
# Epoch 7/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0446
# Epoch 7: val_loss improved from 0.04405 to 0.04314, saving model to best_model.h5
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0446 - val_loss: 0.0431
# Epoch 8/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0412
# Epoch 8: val_loss improved from 0.04314 to 0.03826, saving model to best_model.h5
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0412 - val_loss: 0.0383
# Epoch 9/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0377
# Epoch 9: val_loss did not improve from 0.03826
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0377 - val_loss: 0.0389
# Epoch 10/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 10: val_loss did not improve from 0.03826
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0354 - val_loss: 0.0404
# Epoch 11/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 11: val_loss improved from 0.03826 to 0.03813, saving model to best_model.h5
# 5/5 [==============================] - 0s 107ms/step - loss: 0.0345 - val_loss: 0.0381
# Epoch 12/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 12: val_loss did not improve from 0.03813
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0340 - val_loss: 0.0398
# Epoch 13/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0336
# Epoch 13: val_loss improved from 0.03813 to 0.03758, saving model to best_model.h5
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0336 - val_loss: 0.0376
# Epoch 14/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0330
# Epoch 14: val_loss improved from 0.03758 to 0.03599, saving model to best_model.h5
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0330 - val_loss: 0.0360
# Epoch 15/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0328
# Epoch 15: val_loss did not improve from 0.03599
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0328 - val_loss: 0.0362
# Epoch 16/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0327
# Epoch 16: val_loss improved from 0.03599 to 0.03487, saving model to best_model.h5
# 5/5 [==============================] - 1s 109ms/step - loss: 0.0327 - val_loss: 0.0349
# Epoch 17/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0324
# Epoch 17: val_loss did not improve from 0.03487
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0324 - val_loss: 0.0359
# Epoch 18/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0323
# Epoch 18: val_loss did not improve from 0.03487
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0323 - val_loss: 0.0350
# Epoch 19/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0320
# Epoch 19: val_loss improved from 0.03487 to 0.03366, saving model to best_model.h5
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0320 - val_loss: 0.0337
# Epoch 20/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0319
# Epoch 20: val_loss did not improve from 0.03366
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0319 - val_loss: 0.0352
# Epoch 21/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0318
# Epoch 21: val_loss did not improve from 0.03366
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0317 - val_loss: 0.0343
# Epoch 22/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 22: val_loss improved from 0.03366 to 0.03319, saving model to best_model.h5
# 5/5 [==============================] - 1s 111ms/step - loss: 0.0316 - val_loss: 0.0332
# Epoch 23/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0316
# Epoch 23: val_loss did not improve from 0.03319
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0316 - val_loss: 0.0332
# Epoch 24/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 24: val_loss did not improve from 0.03319
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0314 - val_loss: 0.0339
# Epoch 25/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0314
# Epoch 25: val_loss did not improve from 0.03319
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0314 - val_loss: 0.0346
# Epoch 26/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0313
# Epoch 26: val_loss improved from 0.03319 to 0.03206, saving model to best_model.h5
# 5/5 [==============================] - 1s 110ms/step - loss: 0.0313 - val_loss: 0.0321
# Epoch 27/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0311
# Epoch 27: val_loss did not improve from 0.03206
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0311 - val_loss: 0.0326
# Epoch 28/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0310
# Epoch 28: val_loss did not improve from 0.03206
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0310 - val_loss: 0.0339
# Epoch 29/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 29: val_loss did not improve from 0.03206
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0309 - val_loss: 0.0333
# Epoch 30/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0309
# Epoch 30: val_loss improved from 0.03206 to 0.03168, saving model to best_model.h5
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0309 - val_loss: 0.0317
# Epoch 31/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0308
# Epoch 31: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0308 - val_loss: 0.0324
# Epoch 32/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0307
# Epoch 32: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0307 - val_loss: 0.0324
# Epoch 33/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 33: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0306 - val_loss: 0.0322
# Epoch 34/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0306
# Epoch 34: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0306 - val_loss: 0.0320
# Epoch 35/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0305
# Epoch 35: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0305 - val_loss: 0.0319
# Epoch 36/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0304
# Epoch 36: val_loss did not improve from 0.03168
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0304 - val_loss: 0.0322
# Epoch 37/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0303
# Epoch 37: val_loss improved from 0.03168 to 0.03165, saving model to best_model.h5
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0303 - val_loss: 0.0317
# Epoch 38/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 38: val_loss improved from 0.03165 to 0.03082, saving model to best_model.h5
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0302 - val_loss: 0.0308
# Epoch 39/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 39: val_loss did not improve from 0.03082
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0302 - val_loss: 0.0313
# Epoch 40/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0302
# Epoch 40: val_loss did not improve from 0.03082
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0302 - val_loss: 0.0310
# Epoch 41/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 41: val_loss did not improve from 0.03082
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0301 - val_loss: 0.0315
# Epoch 42/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0301
# Epoch 42: val_loss did not improve from 0.03082
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0301 - val_loss: 0.0317
# Epoch 43/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0300
# Epoch 43: val_loss did not improve from 0.03082
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0300 - val_loss: 0.0310
# Epoch 44/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0299
# Epoch 44: val_loss improved from 0.03082 to 0.03081, saving model to best_model.h5
# 5/5 [==============================] - 1s 125ms/step - loss: 0.0299 - val_loss: 0.0308
# Epoch 45/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0299
# Epoch 45: val_loss improved from 0.03081 to 0.03042, saving model to best_model.h5
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0299 - val_loss: 0.0304
# Epoch 46/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0298
# Epoch 46: val_loss did not improve from 0.03042
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0298 - val_loss: 0.0306
# Epoch 47/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0298
# Epoch 47: val_loss did not improve from 0.03042
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0298 - val_loss: 0.0307
# Epoch 48/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 48: val_loss did not improve from 0.03042
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0297 - val_loss: 0.0307
# Epoch 49/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 49: val_loss did not improve from 0.03042
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0297 - val_loss: 0.0306
# Epoch 50/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0297
# Epoch 50: val_loss did not improve from 0.03042
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0297 - val_loss: 0.0306
# Epoch 51/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 51: val_loss improved from 0.03042 to 0.02978, saving model to best_model.h5
# 5/5 [==============================] - 0s 100ms/step - loss: 0.0295 - val_loss: 0.0298
# Epoch 52/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0295
# Epoch 52: val_loss improved from 0.02978 to 0.02975, saving model to best_model.h5
# 5/5 [==============================] - 1s 104ms/step - loss: 0.0295 - val_loss: 0.0298
# Epoch 53/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 53: val_loss did not improve from 0.02975
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0294 - val_loss: 0.0308
# Epoch 54/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 54: val_loss did not improve from 0.02975
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0294 - val_loss: 0.0304
# Epoch 55/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0294
# Epoch 55: val_loss did not improve from 0.02975
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0294 - val_loss: 0.0301
# Epoch 56/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 56: val_loss improved from 0.02975 to 0.02949, saving model to best_model.h5
# 5/5 [==============================] - 0s 98ms/step - loss: 0.0293 - val_loss: 0.0295
# Epoch 57/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 57: val_loss improved from 0.02949 to 0.02910, saving model to best_model.h5
# 5/5 [==============================] - 1s 105ms/step - loss: 0.0293 - val_loss: 0.0291
# Epoch 58/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0292
# Epoch 58: val_loss did not improve from 0.02910
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0292 - val_loss: 0.0292
# Epoch 59/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 59: val_loss improved from 0.02910 to 0.02866, saving model to best_model.h5
# 5/5 [==============================] - 0s 103ms/step - loss: 0.0291 - val_loss: 0.0287
# Epoch 60/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 60: val_loss improved from 0.02866 to 0.02849, saving model to best_model.h5
# 5/5 [==============================] - 1s 106ms/step - loss: 0.0293 - val_loss: 0.0285
# Epoch 61/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0291
# Epoch 61: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0291 - val_loss: 0.0289
# Epoch 62/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0290
# Epoch 62: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0290 - val_loss: 0.0296
# Epoch 63/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0290
# Epoch 63: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0290 - val_loss: 0.0291
# Epoch 64/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 64: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0288 - val_loss: 0.0287
# Epoch 65/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0290
# Epoch 65: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0290 - val_loss: 0.0286
# Epoch 66/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 66: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0288 - val_loss: 0.0287
# Epoch 67/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0288
# Epoch 67: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0288 - val_loss: 0.0289
# Epoch 68/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 68: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0287 - val_loss: 0.0288
# Epoch 69/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 69: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0287 - val_loss: 0.0289
# Epoch 70/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0285
# Epoch 70: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 70ms/step - loss: 0.0286 - val_loss: 0.0289
# Epoch 71/500
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0286
# Epoch 71: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0287 - val_loss: 0.0292
# Epoch 72/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0287
# Epoch 72: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0287 - val_loss: 0.0290
# Epoch 73/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 73: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0285 - val_loss: 0.0288
# Epoch 74/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 74: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0285 - val_loss: 0.0288
# Epoch 75/500
# 5/5 [==============================] - ETA: 0s - loss: 0.0285
# Epoch 75: val_loss did not improve from 0.02849
# 5/5 [==============================] - 0s 76ms/step - loss: 0.0285 - val_loss: 0.0290
# Epoch 75: early stopping

# %%
# Out:
# 3/3 [==============================] - 0s 9ms/step

# %%
import matplotlib.pyplot as plt

pred = model.predict(f_test).reshape(-1, ds.latitude.size, ds.longitude.size)

seed = 0 
features = f_test[seed].reshape(window_size, ds.latitude.size, ds.longitude.size)
target = t_test[seed]

fig, ax = plt.subplots(1, window_size + 2, figsize=(20, 5))
for i in range(window_size):
    ax[i].imshow(features[i])
    ax[i].set_title(f'Input {i}')

ax[window_size].imshow(target)
ax[window_size].set_title('Target')

ax[window_size + 1].imshow(pred[0])
ax[window_size + 1].set_title('Prediction')

plt.colorbar(ax[window_size + 1].imshow(pred[0]), ax=ax[window_size + 1])

plt.tight_layout()
plt.show()
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
pred.shape, t_test[0].shape
# Out:
# ((70, 10, 30), (10, 30, 1))

# %%
fig, ax = plt.subplots(10, 2, figsize=(20, 50))

pred_ = model.predict(f_test[0:1])  
pred = pred_.reshape(-1, ds.latitude.size, ds.longitude.size)

for i in range(10):
    ax[i, 0].imshow(t_test[i])
    ax[i, 0].set_title(f'Target {i + 1}')


    im = ax[i, 1].imshow(pred[0])
    ax[i, 1].set_title(f'Prediction {i + 1}')

    plt.colorbar(im, ax=ax[i, 1])

    pred_ = model.predict(pred_)
    pred = pred_.reshape(-1, ds.latitude.size, ds.longitude.size)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 10ms/step
